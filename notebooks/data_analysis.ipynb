# %%
import sys
import os

# Add the project root directory to Python path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from library.data_analysis import StockAnalysis

# Create an instance
analyzer = StockAnalysis()

# %%
# Get the distinct values of the symbol column in the stock_prices table
analyzer.get_distinct_values("symbol", table_name="stock_prices")
# Out:
# ['AAPL', 'AMZN', 'GOOG', 'GOOGL', 'JPM', 'META', 'MSFT', 'NVDA', 'PG', 'TSLA']

# %%
# Plot a single stock
analyzer.plot_price_history("GOOG", start_date="2023-01-01");

# %%
# Compare multiple stocks
analyzer.compare_stocks(["MSFT", "GOOG", "AMZN"], start_date="2023-01-01");

# %%
# Create a comprehensive dashboard
analyzer.create_performance_dashboard("GOOG", start_date="2023-01-01");

# %%
analyzer.create_performance_dashboard("MSFT", start_date="2023-01-01");

# %%
analyzer.create_performance_dashboard("AMZN", start_date="2023-01-01");
